# %% [markdown]
# # Operaciones
#
# En esta area se realizan las operaciones aritmeticas 'basicas'

# %%
suma = 4 + 2
resta = 4 - 2
multi = 4 * 2
div = 10 / 3 
divEntera = 10 // 3

# %% [markdown]
# ## Generar Salida
#
# Mediante la utilizacion de un String literal se construye la salida
#
# ```python
# numero = 10
# salida = f'Salida de una
